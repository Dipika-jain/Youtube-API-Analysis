# %%
import googleapiclient.discovery 
import pandas as pd
import seaborn as sns

# %%
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyCccBSShoAlNLayM9lrDgnyX5QMHvA2NC4"
channel_id=[]
channel_ids=['UCNU_lfiiWBdtULKOw6X0Dig',#krish naik
             'UCkw4JCwteGrDHIsyIIKo4tQ',#edureka
             'UCh9nVJoWXmFb7sLApWGcLPQ',#codebasics
             'UCsvqVGtbbyHaMoevxPAq9Fg'#simplilearn
            ]
youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %% [markdown]
# # Function to get channel statistics

# %%
def get_channel_stats(youtube,channel_ids):
    all_data=[]
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids))
    response = request.execute()
    for i in range(len(response)):
        data=dict(Channel_name=response['items'][i]['snippet']['title'],
                 Subscribers=response['items'][i]['statistics']['subscriberCount'],
                 Views=response['items'][i]['statistics']['viewCount'],
                 Total_videos=response['items'][i]['statistics']['videoCount'],
                 playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
       
        all_data.append(data)
    return all_data

# %%
channel_stats=get_channel_stats(youtube,channel_ids)

# %%
channel_data=pd.DataFrame(channel_stats)

# %%
channel_data
# Out:
#   Channel_name Subscribers      Views Total_videos               playlist_id
# 0     edureka!     3950000  416005034        11072  UUkw4JCwteGrDHIsyIIKo4tQ
# 1   codebasics      977000   70824452          827  UUh9nVJoWXmFb7sLApWGcLPQ
# 2  Simplilearn     3860000  344072556         7341  UUsvqVGtbbyHaMoevxPAq9Fg
# 3   Krish Naik      915000   93321718         1837  UUNU_lfiiWBdtULKOw6X0Dig

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers     object
# Views           object
# Total_videos    object
# playlist_id     object
# dtype: object

# %%
channel_data['Subscribers']=pd.to_numeric(channel_data['Subscribers'])
channel_data['Views']=pd.to_numeric(channel_data['Views'])
channel_data['Total_videos']=pd.to_numeric(channel_data['Total_videos'])

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax=sns.barplot(x='Channel_name',y="Subscribers",data=channel_data)

# %%
ax=sns.barplot(x='Channel_name',y="Views",data=channel_data)

# %%
ax=sns.barplot(x='Channel_name',y="Total_videos",data=channel_data)

# %% [markdown]
# # Function to get videos ids

# %%
def get_video_ids(youtube,playlist_id):
    request=youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id,
        maxResults=50
    )
    response=request.execute()
    video_ids=[]
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    next_page_token=response.get('nextPageToken')
    more_pages=True
    while more_pages:
        if next_page_token is None:
            more_pages=False
        else:
            request=youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_page_token
            )
            response=request.execute()
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            next_page_token=response.get('nextPageToken')
            
    return (video_ids)

# %%
playlist_id1=channel_data.loc[channel_data['Channel_name']=='codebasics','playlist_id'].iloc[0]
video_ids=get_video_ids(youtube,playlist_id1)

# %%
video_ids
# Out:
# ['bA_w1wnpRqs',
#  'fQte57VWmxc',
#  '7U2BRYTyb6Y',
#  'lisHrl8WyqM',
#  'aPObz17OyH8',
#  '8zA9UR4oHnk',
#  'IJi5rIP-kXE',
#  '_h9Srjy_dms',
#  'TrRF1S3b0dY',
#  '8FLNFux2NKY',
#  '2hcng6nrl_U',
#  '5RgdtKW4lJs',
#  'dRu1vWnagr8',
#  'nMfsZINX1pc',
#  'fOImcrOpJ9w',
#  'eMtmD9XTbv0',
#  '-pZdzvuVPhA',
#  'ua28OTpiEqo',
#  '8EtgYlQstFY',
#  'MhCHrvfAXlc',
#  'f2FclSWIPF8',
#  'ifVsFd2jpo0',
#  'hvTtdrLueRE',
#  'JpMwWdev4fk',
#  'HkD6C1sq2PM',
#  'UDNq_hpP5RE',
#  'xxRTKxn-lWA',
#  'jB8R5U30Kuo',
#  'AC1yvJk-Op0',
#  'PR9YFHG-5WA',
#  's-Yt37xTBM4',
#  'yJlUhf3V9ZM',
#  'ike7hPIa_CQ',
#  'oaJw0KZjOVU',
#  'aQcGKLVcP_8',
#  '14xzm6SryKg',
#  'acA7eHcI570',
#  'GqH8XD5NcK0',
#  'FNp0q9S3bVA',
#  '_VQv50kCDRU',
#  'aNbY1XyuEPI',
#  'BkJV6hC7-4M',
#  'f_UY4NRtMsg',
#  '1Dc74GT082Y',
#  'BrIcY6xsBoM',
#  'oq3RudE4qLs',
#  '1-o9uFB0KAE',
#  'ygVX2HUEb8U',
#  'C9iVQtsMEfs',
#  'VtvyBM9Wp8U',
#  'OHqZxB8IJjg',
#  '7SKCVMIj4LE',
#  'Amh7BPEUEXc',
#  'hK_ziZw-Ci8',
#  'ho09AtzTIl4',
#  'P8soLmZmG4c',
#  'a-_9YrzZ9ok',
#  'FG4yDbhVjNs',
#  'qTIUoOlvEsI',
#  '5di-uBBHHsQ',
#  'ykpURfngeeE',
#  'PFPt6PQNslE',
#  'qaHGFkw5c_I',
#  'pfktUn0Qblo',
#  'mLr90HJ5Wns',
#  'E-UHJgOpEvw',
#  'eKNZQEyf7qw',
#  'ExsovxBVP98',
#  '2iI6VMalfSc',
#  'XHyTg-zY4TI',
#  'bCLBdxfe57o',
#  'n7R3HGnmg1I',
#  'PEioMvxdFbY',
#  '5CXS1ZaDBT8',
#  'upnUouhuvh0',
#  'qaHLR9Wn1S4',
#  'BOb2a0WBpnU',
#  '0BISRfRSUK0',
#  'pQ0KR1rCw5Q',
#  'PD92bKBnmJA',
#  'C3ZWLvS00qo',
#  '-PkFny6NSu4',
#  'ifzSTgj2JAE',
#  'GC5LwJ7dl64',
#  'fRiYm-N71BI',
#  'GJlxjccMa_Y',
#  'QpaT_tFQopI',
#  'sFRcGlZlGl0',
#  'lj-AFkVe9p4',
#  'ehhST5Kh1Js',
#  '1X0qlb_kog0',
#  'cjVS7YSAu04',
#  'a12Q35lN1UA',
#  'AOggOfOoH1E',
#  'YscmLNPKKCQ',
#  '0STljcKAHKY',
#  'tURuHBxpRxc',
#  'fpsRpvC7ObA',
#  'nSyDNTPoAAg',
#  'ROHintcEd2U',
#  'odS-6Yt8r7E',
#  'Km2ZEgJmR3o',
#  'CwoldAqcJQA',
#  'PAAg9KHs0uI',
#  'zgnYyIkD4dw',
#  'Vqn1Vn9Pzr4',
#  'ljO7Iln9xM4',
#  'hcxLe5XOdWE',
#  'tWn423UcgLs',
#  'vBzygcF_Vpk',
#  'rv0Gca8cbmU',
#  'VxBx8la8ayg',
#  'IoxdtW7Ankw',
#  '1zPjVS5SIAc',
#  'DsUjC6j3xWE',
#  '6MPysOMATPY',
#  'oFvhL9zrdTs',
#  'Uw53Yo93fMA',
#  '1yKHpzbhfTc',
#  'vbvrX5yPEgk',
#  '9IgyK38QMA8',
#  'el7gXhISEcs',
#  'iJvs6NVQrvk',
#  'CwEYZ-RJi0s',
#  '4wtrl4hnPT8',
#  's9XgJvyU_MQ',
#  'ge9zJTiUjZA',
#  '_Utd1QmxYlU',
#  'C3FRtYN8lGI',
#  'eeNq4VpBezs',
#  'D3vmofMmFBg',
#  'AjQPRomyd-k',
#  'blZbbrQpP84',
#  '0rlvVn5R2P4',
#  'l9DPw0ESQ1Q',
#  'SzKZUlf8sm0',
#  'VCocqboGRo4',
#  '5v402p6ydjw',
#  'oYtm5j63MlY',
#  'dPCO4obi158',
#  'iBB9hAW9Nis',
#  'WcxvKYknRU0',
#  'EaGA9eZW1aI',
#  'YhiiJ3vWG-s',
#  '2CY-Fxkdny8',
#  'oqzmJ1QQ4hE',
#  'qpkYgvSmDmw',
#  'JHhXW-o08vk',
#  'p_LdvnTUtvM',
#  '8ju3scaaUi8',
#  'FzGoNV_zKoM',
#  'NNFZ8uuvmUQ',
#  'bqnmlgPnHWo',
#  'SAZPPitf_QY',
#  'yPUorMsjt5E',
#  's6lRU0nn_nw',
#  'qrIhx8Aeef4',
#  'pH3wMYmZ0dM',
#  'iKkod8gj9bs',
#  'ROcFzxXm6hE',
#  'nF-em83yyK4',
#  '6ZXHNuwAnPw',
#  '20US5sfG-j8',
#  'otdiLsyzv90',
#  'WkBFJjUIeOE',
#  'mR2Q-zm3PR4',
#  'ahPqEh-F3Vo',
#  'xLLY1OZjyoI',
#  's-vNTTr_jFI',
#  'huWr4E88ZoI',
#  'k1Zkg4uwlIc',
#  'MoqgmWV1fm8',
#  'tLsQx-3HeQI',
#  'px0Oz0nRz4c',
#  'E-ech-D96V4',
#  'S6CauisUELY',
#  '53nrpoqMpbw',
#  'z4PkyYd7FUI',
#  'vk1B1TmTmqg',
#  'kfjH9nHve-8',
#  'IoHEuhPPwRA',
#  '2qlVv4QS5B4',
#  'NimKbtap1lU',
#  'nGouSpt5elg',
#  'wNbq6DxFcwU',
#  '72XgD322wZ8',
#  'YCA1inoLmQQ',
#  'Ouq0cCtqefE',
#  'JC66t9eM10s',
#  'GkQCChXvxw0',
#  'b6gnP72mlyw',
#  'ZU2qL_AbkBw',
#  '-JOoeynadEQ',
#  't81gqBvOr7o',
#  'rNJR2NhS2Ec',
#  '35mZDywp3TU',
#  'J5usVbAoB9c',
#  '6-UByNVIHwU',
#  'WPSh2xaui_s',
#  'RmpuqY8_ZLw',
#  'XClkezjOtJY',
#  'AIzjiGlwr5I',
#  'tH7lTK_CeJU',
#  'tI7EZNjRHdE',
#  'fXzSgmyDjWg',
#  '7r5rqK7GHEY',
#  'xTvdsMRiF6c',
#  'jewh3qEGd0A',
#  '67_aMPDk2zw',
#  'p5lPAxM0VRY',
#  'FtONvNGAJYk',
#  '7lfc9hVQ1VM',
#  'MFaJazhXrcc',
#  'ANMpBit5cV4',
#  'jahO4DDS2LY',
#  'mpnh6XdYpFc',
#  '37Aqp2BixiM',
#  'bd3KtLYRpB4',
#  'uSLQKYsEYMo',
#  'Rm0xH2Vpfi0',
#  'npgbI8KYvN8',
#  'tku5zP1VzXA',
#  'xP_ZON_P4Ks',
#  'nAmC7SoVLd8',
#  '2e5pQqBvGco',
#  'SHUWIeoiEH4',
#  'ZeoqOybAzdc',
#  'HlBu3fsmZX0',
#  'jhHnqag43WM',
#  'Gw6hVMzna7g',
#  'T8ryqTyVye4',
#  'f-Zf5eWSW3k',
#  '8n-zu2sDt1M',
#  'CQZdrA-hqCo',
#  '__4BIPqNDbk',
#  'vBmYnaMz0kk',
#  'wKqt7ThgR1g',
#  'MZezGuA9dKU',
#  'y9p6tWgXa20',
#  'in3IB45YEgY',
#  'IJCcHDLv7ss',
#  'hQvCOBv_-LE',
#  'LYSaxDQbf2k',
#  'vL4yC-wyKu8',
#  'nkvInnpuic8',
#  'tT4V7zguCnc',
#  '-doYCOojY4w',
#  'iaeKdiBu5Hs',
#  'MaaphT465_I',
#  'sUTr-qs0u20',
#  'L7a1QBJdbzg',
#  'dzTwpJ1J2rs',
#  'yboN-5jHVAY',
#  'b_n-hhtMbXA',
#  '6erwYj4T86c',
#  '0fEipHY0XEQ',
#  'KOmGPNS-YM8',
#  '4QkYy1wANXA',
#  'fHw188SBb9k',
#  'q50JqHQLOQU',
#  'qMShq1Wi0Uc',
#  'kptvgGQ2nSY',
#  'dZbaRYSy9Zo',
#  'HGtWxyUQ1xg',
#  '6KK0qilW7qU',
#  'ezrT1H-6DMY',
#  'tD_sQSzq6uY',
#  'asOnUFHlvZw',
#  'zh-xQp508Vk',
#  'Cq_pbQYO3M8',
#  'Br-Ozg9D4mc',
#  '2lfLPAfU40g',
#  'ZrgVlfNduj8',
#  'aiX9hyxVcL8',
#  '0r2NJdalzDw',
#  'ibi5hvw6f3g',
#  'vyohzuTkty8',
#  'hwuCesO6BTk',
#  'Q-x0xwHAOUQ',
#  'woGM7Mgz7ZQ',
#  '7Mp82bRhvW0',
#  'QOyHqOrn2DE',
#  'Rn0LyHJujF4',
#  'PaoXRxgEQp8',
#  'W7lmbinPNW8',
#  'Do8cVbx-HOs',
#  'uRrQLefb4-I',
#  'q0-XCIu0fSc',
#  'v_enwVAvsyQ',
#  'DwgC72_s-T4',
#  'MlDjrcnwAhw',
#  'ru1qeDO_qrc',
#  'WZui2hPyjw4',
#  'yd2FVTDGj9s',
#  'bOIEF_ol0vM',
#  'T4rlTsr1e7g',
#  'oQUlpvA-0rs',
#  'T-rAYiNjvbk',
#  'y42CzmzMk68',
#  'zSgmrWQa03s',
#  'wg15SqQHr9w',
#  'uz1lM4aKMcU',
#  'ATK6fm3cYfI',
#  'nZromH6F7R0',
#  'jfpdr9j94_k',
#  'vUPAOU2NPls',
#  '6jfARpCukyo',
#  'xAVbBgDrwLo',
#  'Yt1Sw6yWjlw',
#  'Mz-0ofqx5M8',
#  'WROHCDfiBp0',
#  'hzzvCrg4nr0',
#  '2d8iP2_cS-U',
#  'HuZiJ44_71M',
#  'hsJidtpHHyo',
#  'FD9b73JXpYY',
#  'G3uclekof0c',
#  '_3ahmI5vpKY',
#  'W8o6dq3kisM',
#  'ttYc9I2YrFY',
#  'LlD2hNyjjLg',
#  'imaOMwNcE7M',
#  '3hY3YmwyU_s',
#  'yFNMgIUiXuM',
#  'nqnLhy0A-Es',
#  'buQSI8NLOMw',
#  'xaKOvuffxRw',
#  '2XUhKpH0p4M',
#  'ltOAU5qu9sc',
#  'cElCnuA40os',
#  'GUZwFRs9f5c',
#  'poHVmxGpvW8',
#  'gdHWoQWZGkk',
#  'slQDeuWiD7U',
#  'RjSgdRjmlSA',
#  'HHAilAC3cXw',
#  'zB0Ap_SlVao',
#  'VrgB8GyjYYM',
#  '52rAq9Zmyiw',
#  'hKK59rfpXL0',
#  'kmtbfkGlqvI',
#  '_lR3RjvYvF4',
#  'wHF99-BYvgU',
#  'UnVyNh6P6FQ',
#  'Eb-YWlxHiQM',
#  'h2kBNEShsiE',
#  '1KaQImCTG6A',
#  'S3EId9uatxI',
#  'tB2dp6OKoz8',
#  '4Y2cm77SUxw',
#  'LUr1OZgVhVk',
#  'wauwRR1pEbg',
#  'Zcdy1BpozW0',
#  'HLU4oDOinzo',
#  'VohANmgEx7Y',
#  'In7jB8TUGPA',
#  'R6u5EBWAssY',
#  'mdQRqba2AwQ',
#  'f_csX16Y5e8',
#  'nknYY32RGXQ',
#  'yaGEgVgZxMo',
#  '-7WTKWBckUY',
#  'lK9gx4q_vfI',
#  '3y2-IaBeIs0',
#  'zq3v8lEfIUk',
#  'R-AG4-qZs1A',
#  'dQ7Okl0XY_s',
#  'Yt3PQU_qEtc',
#  'iyvxI_Ah3qc',
#  'NWVindWhIX8',
#  'BFCky7ZnqO8',
#  '0lQHPcYYfWA',
#  'm7KWxX23zCU',
#  'yXEZr2fg3TY',
#  '3lT8BHmEOfk',
#  'IiMlBs-yePg',
#  'GRzb3x7I6B8',
#  'sHw5hLYFaIw',
#  'fIsXdtcn09U',
#  '6FVcIa4MXXE',
#  '43q4nGka5SE',
#  'XV8Gn9aEbQ8',
#  '957fQCm5aDo',
#  'J4uXuHqxVdg',
#  'eD3Zsb6w7K4',
#  'XXv4lMQP6uw',
#  'jZRi3i9I644',
#  'f_xzBcBBcTs',
#  'RtrBtAKwcxQ',
#  'B01qMFMAgUQ',
#  'Ll1BLZBSLQ8',
#  'bswlUucUuMk',
#  '8klqIM9UvAc',
#  'CQveSaMyEwM',
#  'Avgl_ZwKVV8',
#  'fb8BSFr0isg',
#  'mSf0j8qkkFI',
#  'XH945kBzbdA',
#  'unTRt_gK7Jk',
#  'eiIhTbFP0ls',
#  'ra4j7yDlakQ',
#  'DQFerxe6o5g',
#  '-kduEAqShbc',
#  'wqxQDCXLRnY',
#  'vMtIlFmZKxQ',
#  'hOCDJyZ6quA',
#  'JLJwOP1Djdw',
#  'lXZn3eDFDgE',
#  'uldlsT98Bbs',
#  't6NI0u_lgNo',
#  'ZN6P_GEJ7lk',
#  'bns5ELvbzVk',
#  'dGtDTjYs3xc',
#  'Wr1JjhTt1Xg',
#  'xK5zAg5TZUk',
#  '9VSzXt9pD5U',
#  'v1oHf1KV6kM',
#  'IMSnp4hTHYQ',
#  'rAIfuWRM96A',
#  'P-5sMcpTE0g',
#  'sJzuNAisXHA',
#  't-kiCW0jdLg',
#  'QqeHli7YyOQ',
#  'D9yyt6BfgAM',
#  '7kLi8u2dJz0',
#  'icGPvdH4PJo',
#  'm_CooIRM3UI',
#  'dLExQ6yc7e4',
#  'A0jr2lwvRik',
#  'o6nFv0UfEdI',
#  'yKB6EUbGamo',
#  'wUK_k1GHEtw',
#  'HCbZujfzDEc',
#  'z_96KlOS92o',
#  'MLEKEplgCas',
#  '5c6Q97eOQ8o',
#  'VFEOskzhhbc',
#  '89amFKwlb0M',
#  '5HaWRGcTTyg',
#  '95OyAjIZAbs',
#  's3N2Vg976yQ',
#  '-LVdJuNzmU0',
#  'nd4In7EkBOQ',
#  'Q2NtCcqmIww',
#  'iIYYGeKD5mQ',
#  '9KyixVtWumE',
#  'ABr9ZAkeiiU',
#  'xtTX69JZ92w',
#  'T4MLrtOKPjY',
#  'Yqj_w_wjZmY',
#  'YaWE3qkzmDI',
#  't4LOv9h-FJM',
#  'SPExESsO4ok',
#  'okhrFgaUwio',
#  'yCDevFTNbC0',
#  '8ZI55Inh1_A',
#  'KzQQCtgzQbw',
#  'Fsqga8GeO2g',
#  '7sFRpbPKTG4',
#  'x101rSKpESk',
#  '5TRr2oWeSw0',
#  'C07T45z-iWs',
#  'FMs09SG4ePU',
#  'm684QWvVDTA',
#  'QAsZgzLPaWU',
#  'hQwFeIupNP0',
#  '1KnNhd5TE7o',
#  'n9Jelsno0TA',
#  'dWwTWXVxnbw',
#  'F1ZnbUjrSbU',
#  'Fuw0wv3X-0o',
#  'qHlpvKjA-lk',
#  'pXuTupqq0xg',
#  'Ik2I2zc234s',
#  'qFNBaiepRXc',
#  'sZGuyTLjsco',
#  '4BLxapDqrlA',
#  '-nL66ECoFI4',
#  'VYEZpOn-77Y',
#  'cys2otlV3Ng',
#  'HNE0qHJ9A9o',
#  'OIucG2hvdCo',
#  'atYPhweJ7ao',
#  'GD-fqjKFcPI',
#  'BCuJXskWgSI',
#  'tOuXgORsXJ4',
#  'b23kMqp2M7A',
#  'ObmpEe-61go',
#  'HqKgsszV-3Y',
#  '9bsK03SlmNM',
#  '-GmJLI122ZM',
#  'LfnrRPFhkuY',
#  'pqSoCa2NGj4',
#  'uyEIihDoXR8',
#  'qowp6SQ9_Oo',
#  'V4AcLJ2cgmU',
#  'MDu_oiU5EgM',
#  '8Ert2Soaj9U',
#  'n05CmcjOcho',
#  'EzsXi4WzelI',
#  'Y2wfIKQyd1I',
#  'IpawPa1e2o0',
#  'VxOKSzKRB3w',
#  'IfRMV2MY9n0',
#  'ZhnJ1bkIWWk',
#  'rLvpY2v9hWQ',
#  'AoOo5zufdbE',
#  'EArKJnmAgkI',
#  'P1uHDPpe_04',
#  'VNmghbJRv8I',
#  'QC2d2jmdbPM',
#  'ag3DLKsl2vk',
#  'Lxlmcxpmr_g',
#  'uN_yT-5t2hU',
#  'AimW3j7M2Uw',
#  'a2CO-OWk2xo',
#  'XXRtOmI7-kM',
#  '6BLY1IfV-1M',
#  'B2dCCRY_l78',
#  'fgMD2wvpvpk',
#  'ermMcj5FtY4',
#  'CCNd2fUfFkk',
#  'hK058kTWagQ',
#  'oIBpPDOqstw',
#  '9F-GYV2lrwA',
#  'SfqN-Hc5two',
#  'Kh6k7Vh7Rs8',
#  '0d6NTZJ6q6A',
#  'taC5pMCm70U',
#  '9ixxhdVjOV4',
#  'CBsmoxcBAJk',
#  '-JhV-FRQwQQ',
#  'hhkLdjIimlw',
#  'VqKq78PVO9g',
#  'YCgJ2wqJT0A',
#  'LsdxvjLWkIY',
#  'sQnG6XiFfLE',
#  'iAyCX4enaXA',
#  'rJlFUMlKsz0',
#  'NJB6RT0tsLI',
#  'RsK70V-R2N0',
#  'f9PR1qcwOyg',
#  'VQsqdp_I9Ro',
#  '0ZaC6JaNpic',
#  'QQ0_M8OOppg',
#  '9F8zD42hQCA',
#  'ykNwTHRlxN4',
#  's3HmuSlY3uk',
#  '7WR-9yOT7OE',
#  'JdHaZjS18UM',
#  'RpkhOiIn2fM',
#  'd2SetJgqBDQ',
#  'dtBUB5i2d9s',
#  'WH-JNJIITnU',
#  'mTVf7BN7S8w',
#  'VxNr9Vudp4Y',
#  'F7ox6R773OQ',
#  'oDAPkZ53zKk',
#  'e4i_EGAa0gU',
#  '7HPwo4wnJeA',
#  'nCNfu_zNhyI',
#  'zfiSAzpy9NM',
#  'ZajwOKbY3XU',
#  'aDpnaxPAmtU',
#  'cXBK_G5M1Ng',
#  '4rjai6MHqQQ',
#  '4xh1Vek9vnk',
#  'K0zTIF3rm9s',
#  'JMipUHeREIw',
#  'JnlM4yLFNuo',
#  'lcI8ukTUEbo',
#  '87PzGnEzCNc',
#  '5iSZ7mh_RAk',
#  'ppmIOUIz4uI',
#  'GnZ9ppr_zaI',
#  '27u8xHqLMZE',
#  '2osIZ-dSPGE',
#  'MSBY28IJ47U',
#  'OqGHe81tOxE',
#  'oXpJzbXnB4A',
#  'E_IQ3mzZyrw',
#  'YmDaqXMIoeY',
#  'JCGbRDL7F10',
#  '9SdLOcGnebU',
#  'K_oJLQx2ySY',
#  '5ogmEkujoqE',
#  'K5Ek0Y8ji0E',
#  'j0IYCyBdzfA',
#  '5QhqkZxf1js',
#  'IU5fuoYBTAM',
#  'PQCE9ChuIDY',
#  'E1yyaLRUnLo',
#  'pXGBHV3y8rs',
#  'Wibxjrxf5ko',
#  'cT4pQT5Da0Q',
#  'GKGIYPmdXGc',
#  '3r-zD_i4rbs',
#  'icZItWxw7AI',
#  'iqQgED9vV7k',
#  'z-ZR_8BZ1wQ',
#  'VC-EliTgMEM',
#  'ER2It2mIagI',
#  'VhRtaziEWd4',
#  'yfsTZbwgMSE',
#  'Mubj_fqiAv8',
#  '68m2UCtedj0',
#  '95YpbxxTqgI',
#  '_QqhyLfRzb0',
#  'tGxelSFySuI',
#  'ah6-h6nAmcM',
#  'gDuMaJfDtS0',
#  'pbOJVEsZKJ8',
#  '6pifKxjyHd8',
#  'JOrhcV3_NAk',
#  '9QiZ0-HZG_A',
#  'hhZ62IlTxYs',
#  'xucm6_BQPJU',
#  'ep3t8oAvZjs',
#  'j8PnojuLnVo',
#  'W-PmvEeHioQ',
#  'idMKTkfeo4A',
#  'NtNl97LlpOk',
#  'lqEzYDuTnvU',
#  '5Uc_m9CRWro',
#  'sWAPtaBZKBQ',
#  'ny5Mv7wYzFU',
#  'kwKfWBb6frs',
#  'm1dQ38qDABw',
#  'qWXXHjV3JHI',
#  'pOXmn7jP9gQ',
#  '34-RThWWRHM',
#  'YKPFQUvckU0',
#  'ysqAne_0Tu8',
#  'A3gClkblXK8',
#  'KFuEAGR3HS4',
#  'Izk2VJXWSxc',
#  'ubdmKhVJ5I0',
#  '7sJaRHF03K8',
#  'pYVScuY-GPk',
#  'JnrbMQyGLiU',
#  'lFq5mYUWEBk',
#  'BxaeAfVqbXw',
#  'HgE2yOHl1RU',
#  '9fqu2m7O8VI',
#  '3qRu5R00y-4',
#  'yZFrSDjRvjk',
#  '4r_XR9fUPhQ',
#  'HT76DdBCIfU',
#  'rUUrmGKYwHw',
#  'rii6QRX8ZLs',
#  'OeEQtX5umqU',
#  'CptrlyD0LJ8',
#  'zwb3GmNAtFk',
#  '9VQAwhp27eU',
#  '54iv1si4YCM',
#  'ea8BRGxGmlA',
#  'qp8u-frRAnU',
#  '79Wkib0Q87Y',
#  'gDqQf4Ekr2A',
#  '_t2GVaQasRY',
#  'cdDD5t9r98c',
#  'IR_S8BC8KI0',
#  'q8NOmLD5pTU',
#  'YOHfdeBoWMI',
#  'SROp_MAWmSo',
#  'P8BuKf9crA8',
#  'oF_2uDb7DvQ',
#  'x6tnVOn4st4',
#  'q9oAZwhuUy4',
#  'dM_MzB2sCQk',
#  'cbqZa_1vzcg',
#  'rD2xumR98w8',
#  'Q5JyawS8f5Q',
#  'oCiRv94GMEc',
#  'gMoJIH0prL4',
#  '_drqJ9SFCgU',
#  'rdfbcdP75KI',
#  'JL_grPUnXzY',
#  'HdlDYng8g9s',
#  'nHIUYwN-5rM',
#  'PPeaRc-r1OI',
#  '5dxXSXhpMPA',
#  'YHR-4OEbl00',
#  'zyib_6XZW0g',
#  '3ykIpmAxdoY',
#  '66HNCg7_gfE',
#  '6lBPM-MiGNI',
#  '7snh_1Hf_TI',
#  'FNExLliAnZw',
#  'OxpBMNalsDM',
#  'fz_BCnhEQYQ',
#  'hNddJ3_hahk',
#  't0UTQ1eOH_g',
#  '0cQj7q8EWxY',
#  '2AKJzc-cSj8',
#  '6XWeeEg6d3s',
#  '8tCe1P_cgoY',
#  'DdGVBZv46PI',
#  'IVWZxr0kOyI',
#  'RCM-lVAfXFg',
#  'RD6JionMlXM',
#  'Vig1IeU2RYk',
#  'WIqX3kDxDKE',
#  'Z7D9yv21tig',
#  'ez2N-hcwvcQ',
#  'ffFRuB03qLE',
#  'fz2PKpPdlRo',
#  'kqVQDXfc9hU',
#  'pd2_ZbhFT38',
#  'ttMX3Ns_0oY',
#  'EItlUEPCIzM',
#  'gJo0uNL-5Qw',
#  'ok2s1vV9XW0',
#  'FB5EdxAGxQg',
#  'PHxYNGo8NcI',
#  'J5bXOOmkopc',
#  'zM4VZR0px8E',
#  'XYnitrVGaDI',
#  'fwY9Qv96DJY',
#  '9yl6-HEY7_s',
#  'KfnhNlD8WZI',
#  'vsWrXfO3wWw',
#  'J_LnPL3Qg70',
#  '8jazNUpO3lQ',
#  'gmvvaobm7eQ',
#  'M-4EpNdlSuY',
#  'XLJHkCn48lM',
#  'GOuUGWGUT14',
#  'r75BPh1uk38',
#  'iedmZlFxjfA',
#  'oETDriX9n1w',
#  'zl5qPnqps8M',
#  'qqwf4Vuj8oM',
#  'XawR6CjAYV4',
#  '0lsmdNLNorY',
#  '9IW2GIJajLs',
#  '3l9YOS4y24Y',
#  'igWjq3jtLYI',
#  'Fo0IMzfcnQE',
#  'A9c7hGXQ5A8',
#  'r0s4slGHwzE',
#  'I_kUj-MfYys',
#  'BUOy4RUUepg',
#  'dS7oZE8ryxM',
#  'oY62o-tBHF4',
#  'xPPs59pn6qU',
#  'h4hOPGo4UVU',
#  'eykoKxsYtow',
#  'WGOEFok1szA',
#  'Wb2Tp35dZ-I',
#  'XOxABiMhG2U',
#  'EaGbS7eWSs0',
#  '-0NwrcZOKhQ',
#  '3k0HbcUGErE',
#  'F6kmIpWWEdU',
#  'CmorAWRsCAw',
#  'EEEZX_0FMEc',
#  'Vt6loGK9Adc',
#  'q_BzsPxwLOE',
#  '_d_Ka-ks2a0',
#  'a8aDcLk4vRc',
#  'rN0TREj8G7U',
#  '2EGgtlf7BN0',
#  'nYDKH9fvlBY',
#  'IVrGz8w0H8c',
#  'eu_kTGv61WQ',
#  'nv9zw454bEk',
#  'l32bsaIDoWk',
#  'hYws-CDXA7k',
#  '_1ZwkCY9wxk',
#  'POL7n754JTc',
#  'sp7EhjLkFY4',
#  'ErJyWO8TGoM',
#  'uWbSc84he2Q',
#  'Lu5LrKh1Zno',
#  'oIN488Ldg9k',
#  '3Qynj8WUwgs',
#  'ZaI1co-rt9I',
#  'e3bjQX9jIBk',
#  'sgzkY5vFKQQ',
#  '3dk3s4LK-Wg',
#  'eL_0Ok_Gkas',
#  'Bg9IAquDsDg',
#  'xAAmje1H9YM',
#  'ON5GAXubt_4',
#  'PJ4t2U15ACo',
#  'vdYYTIN96H0',
#  'Tjkz4Kt21wI',
#  'kRL6hjWOKWI',
#  'XYUXFR5FSxI',
#  '482kbk1x04w',
#  'MxZwyrIXNjs',
#  'lJUZc3OhU7A',
#  'Fc1fLEk_Kr0',
#  'xiNbGFf_kD0',
#  '4CyTWTFn6JY',
#  'Bar-EdLLV60',
#  'I3oDtQ-fdGo',
#  'bij66_Jtoqs',
#  '8j9jpHkE-4U',
#  'KdIyRbixrYE',
#  'RJe3D6_dKv0',
#  'iHqWIDAjrG8',
#  'jHooi6KKrj0',
#  'mrhccLHtyN4',
#  'cN8GmaL62-4',
#  'MxsSt_X7fuk',
#  'Ia1i5EIGp9k',
#  'x0lI4omOYTw',
#  'Huz6bS0uLm4',
#  'OQbLSccX7po',
#  'cvnHHSK_O6E',
#  'Kf0q4Tf5M3c',
#  'wjfrvLo8QJ4',
#  'YgI94IRXySk',
#  'iM3kh-fDg5o',
#  '2c7nkf1b31s',
#  'rruGL7nD3ss',
#  'nrxA8Pkb90Y',
#  'UZRD8rmOC7M',
#  'BBPoInSOiOY',
#  'Ejrq3yB2DIQ',
#  'pP91kLR5cnE',
#  'PsoKq0p5meU',
#  'YJKEqaaSGDs',
#  'BAoV5_qVKco',
#  'M4ztKyNkDIM']

# %% [markdown]
# # Function to get video details

# %%
def get_video_details(youtube,video_ids):
    all_video_stats=[]
    for i in range(0,len(video_ids),50):
        request=youtube.videos().list(
            part='snippet,statistics',
            id=','.join(video_ids[i:i+50])
        )
        response=request.execute()
        for video in response['items']:
            video_stats=dict(Title=video['snippet']['title'],
                            Published_date=video['snippet']['publishedAt'],
                            Views=video['statistics']['viewCount'],
                            Likes=video['statistics']['likeCount'],
                            Favorite=video['statistics']['favoriteCount']
                             , Comment=video['statistics']['commentCount']
                            )
            all_video_stats.append(video_stats)
    return all_video_stats

# %%
video_details=get_video_details(youtube,video_ids)

# %%
video_data=pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                  Title        Published_date  \
# 0    Career in AI | Which Career Option is the Best...  2024-03-23T13:30:08Z
# 1       Don't put toy dataset projects on your resume!  2024-03-22T12:30:34Z
# 2                   Career Transition to Data Analyst!  2024-03-21T12:30:05Z
# 3                       Do you know the value of time?  2024-03-20T12:30:36Z
# 4    AI Career Opportunities | Career in AI with Sa...  2024-03-19T13:30:08Z
# ..                                                 ...                   ...
# 822                         Python Tutorial - 5. Lists  2015-12-20T23:01:51Z
# 823                       Python Tutorial - 4. Strings  2015-12-20T22:34:19Z
# 824                       Python Tutorial - 3. Numbers  2015-12-20T02:54:56Z
# 825                     Python Tutorial - 2. Variables  2015-12-20T02:11:10Z
# 826     Python Tutorial - 1. Install python on windows  2015-12-20T01:21:07Z
#
#       Views Likes Favorite Comment
# 0     12329   774        0      76
# 1    364475  2489        0      23
# 2      5812   385        0       7
# 3      5405   250        0       6
# 4     42608  1545        0      97
# ..      ...   ...      ...     ...
# 822   34962   319        0      55
# 823   28657   317        0      28
# 824   32478   321        0      31
# 825   42680   333        0      24
# 826   48002   378        0      16
#
# [827 rows x 6 columns]

# %%
video_data.dtypes
# Out:
# Title             object
# Published_date    object
# Views             object
# Likes             object
# Favorite          object
# Comment           object
# dtype: object

# %%
video_data['Published_date']=pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views']=pd.to_numeric(video_data['Views'])
video_data['Likes']=pd.to_numeric(video_data['Likes'])
video_data['Favorite']=pd.to_numeric(video_data['Favorite'])
video_data['Comment']=pd.to_numeric(video_data['Comment'])

# %%
video_data.dtypes
# Out:
# Title             object
# Published_date    object
# Views              int64
# Likes              int64
# Favorite           int64
# Comment            int64
# dtype: object

# %%
top_10_video=video_data.sort_values(by='Views',ascending=False)
top_10_video=top_10_video.head(10)

# %%
top_10_video
# Out:
#                                                  Title Published_date  \
# 356  Reality behind data science, machine learning ...     2022-02-16
# 755  Python Pandas Tutorial 1. What is Pandas pytho...     2017-01-21
# 504  Bitcoin Mining Fundamentals in Python | Python...     2021-01-03
# 724  Machine Learning Tutorial Python -1: What is M...     2018-06-30
# 723  Machine Learning Tutorial Python - 2: Linear R...     2018-07-01
# 575  Complete python roadmap | How to become an exp...     2020-09-13
# 561  Simple explanation of convolutional neural net...     2020-10-14
# 659  Data Structures & Algorithms Tutorial in Pytho...     2020-03-07
# 754         Python Pandas Tutorial 2: Dataframe Basics     2017-01-28
# 752  Python Pandas Tutorial 4: Read Write Excel CSV...     2017-02-04
#
#        Views  Likes  Favorite  Comment
# 356  1545003  68860         0      497
# 755  1119273  12543         0      384
# 504  1104313  31813         0     2666
# 724  1062513  11905         0      228
# 723   966329  12659         0     1276
# 575   882427  30487         0     1033
# 561   824136  18341         0      681
# 659   795241  13080         0      258
# 754   769104  11674         0      454
# 752   675119   9043         0      510

# %%
ax1=sns.barplot(x='Views',y='Title',data=top_10_video)

# %%
video_data
# Out:
#                                                  Title Published_date   Views  \
# 0    Career in AI | Which Career Option is the Best...     2024-03-23   12329
# 1       Don't put toy dataset projects on your resume!     2024-03-22  364475
# 2                   Career Transition to Data Analyst!     2024-03-21    5812
# 3                       Do you know the value of time?     2024-03-20    5405
# 4    AI Career Opportunities | Career in AI with Sa...     2024-03-19   42608
# ..                                                 ...            ...     ...
# 822                         Python Tutorial - 5. Lists     2015-12-20   34962
# 823                       Python Tutorial - 4. Strings     2015-12-20   28657
# 824                       Python Tutorial - 3. Numbers     2015-12-20   32478
# 825                     Python Tutorial - 2. Variables     2015-12-20   42680
# 826     Python Tutorial - 1. Install python on windows     2015-12-20   48002
#
#      Likes  Favorite  Comment
# 0      774         0       76
# 1     2489         0       23
# 2      385         0        7
# 3      250         0        6
# 4     1545         0       97
# ..     ...       ...      ...
# 822    319         0       55
# 823    317         0       28
# 824    321         0       31
# 825    333         0       24
# 826    378         0       16
#
# [827 rows x 6 columns]

# %%
video_data['Month']=pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                  Title Published_date   Views  \
# 0    Career in AI | Which Career Option is the Best...     2024-03-23   12329
# 1       Don't put toy dataset projects on your resume!     2024-03-22  364475
# 2                   Career Transition to Data Analyst!     2024-03-21    5812
# 3                       Do you know the value of time?     2024-03-20    5405
# 4    AI Career Opportunities | Career in AI with Sa...     2024-03-19   42608
# ..                                                 ...            ...     ...
# 822                         Python Tutorial - 5. Lists     2015-12-20   34962
# 823                       Python Tutorial - 4. Strings     2015-12-20   28657
# 824                       Python Tutorial - 3. Numbers     2015-12-20   32478
# 825                     Python Tutorial - 2. Variables     2015-12-20   42680
# 826     Python Tutorial - 1. Install python on windows     2015-12-20   48002
#
#      Likes  Favorite  Comment Month
# 0      774         0       76   Mar
# 1     2489         0       23   Mar
# 2      385         0        7   Mar
# 3      250         0        6   Mar
# 4     1545         0       97   Mar
# ..     ...       ...      ...   ...
# 822    319         0       55   Dec
# 823    317         0       28   Dec
# 824    321         0       31   Dec
# 825    333         0       24   Dec
# 826    378         0       16   Dec
#
# [827 rows x 7 columns]

# %%
videos_per_month=video_data.groupby('Month',as_index=False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr    41
# 1    Aug    72
# 2    Dec    96
# 3    Feb    60
# 4    Jan    81
# 5    Jul    52
# 6    Jun    53
# 7    Mar    57
# 8    May    79
# 9    Nov    81
# 10   Oct    67
# 11   Sep    88

# %%
sort_order=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug'
           ,'Sep','Oct','Nov','Dec']

# %%
videos_per_month.index=pd.CategoricalIndex(videos_per_month['Month'],categories=sort_order,ordered=True)

# %%
videos_per_month= videos_per_month.sort_index()

# %%
ax2=sns.barplot(x='Month',y='size',data=videos_per_month)

# %%
video_data.to_csv('CodeBasics_VideoDetails.csv')
